# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as mcolors
import json
from scipy.stats import wilcoxon
from figures import read_csvs

# %% [markdown]
# # Processing data

# %%
# Loading results
text_behav = read_csvs('../../data/results/rca_ensemb/text_behav/').query('embed != "BERT_base&CBOW_GoogleNews"')
text_brain = read_csvs('../../data/results/rca_ensemb/text_brain/')
text_behav
# Out:
#                      embed                           norm  train_n  fold  \
# 0     BERT_base&Llama_3_8B                 frequency_lund     5815     1
# 1     BERT_base&Llama_3_8B                 frequency_lund     5815     2
# 2     BERT_base&Llama_3_8B                 frequency_lund     5815     3
# 3     BERT_base&Llama_3_8B                 frequency_lund     5815     4
# 4     BERT_base&Llama_3_8B                 frequency_lund     5815     5
# ...                    ...                            ...      ...   ...
# 4360    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     1
# 4361    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     2
# 4362    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     3
# 4363    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     4
# 4364    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     5
#
#             r2 check
# 0     0.821387  pass
# 1     0.816372  pass
# 2     0.837488  pass
# ...

# %%
# Loading norm metadata
meta = pd.read_csv('../../data/psychNorms/psychNorms_metadata.csv', index_col=0)

def norms_to_cats(norms: pd.Series) -> pd.Series:
    return norms.apply(lambda norm: meta.loc[norm]['category']).replace({'_': ' '}, regex=True)

# Adding norm categories
text_behav['norm_cat'] = norms_to_cats(text_behav['norm'])
text_brain['norm_cat'] = norms_to_cats(text_brain['norm'])

text_behav
# Out:
#                      embed                           norm  train_n  fold  \
# 0     BERT_base&Llama_3_8B                 frequency_lund     5815     1
# 1     BERT_base&Llama_3_8B                 frequency_lund     5815     2
# 2     BERT_base&Llama_3_8B                 frequency_lund     5815     3
# 3     BERT_base&Llama_3_8B                 frequency_lund     5815     4
# 4     BERT_base&Llama_3_8B                 frequency_lund     5815     5
# ...                    ...                            ...      ...   ...
# 4360    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     1
# 4361    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     2
# 4362    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     3
# 4363    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     4
# 4364    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     5
#
#             r2 check   norm_cat
# 0     0.821387  pass  frequency
# ...

# %%
with open('../../data/embed_to_dtype.json', 'r') as f:
    embed_to_type = json.load(f)

def embed_to_group(embed_name: str) -> str:
    if '&' in embed_name:
        name_1, name_2 = embed_name.split('&')
        return embed_to_type[name_1] + '&' + embed_to_type[name_2]
    else:
        return embed_to_type[embed_name]

text_behav['embed_group'] = text_behav['embed'].apply(embed_to_group)
text_brain['embed_group'] = text_brain['embed'].apply(embed_to_group)

text_behav
# Out:
#                      embed                           norm  train_n  fold  \
# 0     BERT_base&Llama_3_8B                 frequency_lund     5815     1
# 1     BERT_base&Llama_3_8B                 frequency_lund     5815     2
# 2     BERT_base&Llama_3_8B                 frequency_lund     5815     3
# 3     BERT_base&Llama_3_8B                 frequency_lund     5815     4
# 4     BERT_base&Llama_3_8B                 frequency_lund     5815     5
# ...                    ...                            ...      ...   ...
# 4360    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     1
# 4361    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     2
# 4362    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     3
# 4363    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     4
# 4364    BERT_base&SVD_SWOW  sensory_experience_juhasz2013     3683     5
#
#             r2 check   norm_cat    embed_group
# ...

# %%
def compute_mean_results(results: pd.DataFrame) -> pd.DataFrame:
    means = (
        results[['embed_group', 'norm', 'r2', 'norm_cat']]
        .groupby(['embed_group', 'norm'], as_index=False)
        .agg(r2_mean=('r2', 'mean'), norm_cat=('norm_cat', 'first'))
    )
    return means

text_behav_mean = compute_mean_results(text_behav)
text_brain_mean = compute_mean_results(text_brain)

text_behav_mean
# Out:
#        embed_group                        norm   r2_mean  \
# 0    text&behavior              anger_mohammad  0.370043
# 1    text&behavior             anger_stevenson  0.797598
# 2    text&behavior                angry_binder  0.614686
# 3    text&behavior                 angry_zupan  0.721540
# 4    text&behavior       anticipation_mohammad  0.166047
# ..             ...                         ...       ...
# 577      text&text  visual_lexical_rt_keuleers  0.493710
# 578      text&text   visual_lexical_rt_mandera  0.435390
# 579      text&text               visual_lynott  0.603759
# 580      text&text               visual_troche  0.801949
# 581      text&text               weight_binder  0.646470
#
#                     norm_cat
# 0                    emotion
# 1                    emotion
# 2                    emotion
# 3                    emotion
# 4                    emotion
# ..                       ...
# 577  visual lexical decision
# 578  visual lexical decision
# ...

# %% [markdown]
# **Grand avgs**

# %%
def compute_grand_avg_results(means: pd.DataFrame) -> pd.DataFrame:
    grand_avgs = (
        means[['embed_group', 'norm_cat', 'r2_mean']]
        .groupby(['embed_group', 'norm_cat'], as_index=False)
        .agg(r2_grand_avg=('r2_mean', 'median'))
    )
    return grand_avgs

text_behav_grand = compute_grand_avg_results(text_behav_mean)
text_brain_grand = compute_grand_avg_results(text_brain_mean)

text_behav_grand
# Out:
#       embed_group                   norm_cat  r2_grand_avg
# 0   text&behavior         age of acquisition      0.591720
# 1   text&behavior                    animacy      0.781283
# 2   text&behavior                    arousal      0.625402
# 3   text&behavior            associatability      0.399907
# 4   text&behavior  auditory lexical decision      0.096556
# 5   text&behavior               concreteness      0.801086
# 6   text&behavior                  dominance      0.631743
# 7   text&behavior                    emotion      0.626395
# 8   text&behavior                familiarity      0.337986
# 9   text&behavior                  frequency      0.783100
# 10  text&behavior                goals/needs      0.612886
# 11  text&behavior     iconicity/transparency      0.350352
# 12  text&behavior               imageability      0.681774
# 13  text&behavior                      motor      0.586961
# 14  text&behavior                     naming      0.177871
# ...

# %%
# Getting overall ordering
text_behav_grand.groupby('embed_group')['r2_grand_avg'].mean().sort_values(ascending=False)
# Out:
# embed_group
# text&text        0.531950
# text&behavior    0.527929
# Name: r2_grand_avg, dtype: float64

# %%
text_brain_grand.groupby('embed_group')['r2_grand_avg'].mean().sort_values(ascending=False)
# Out:
# embed_group
# text&text     0.393795
# text&brain    0.363109
# Name: r2_grand_avg, dtype: float64

# %% [markdown]
# **grand avg diffs**

# %%
def pivot_results(results: pd.DataFrame) -> pd.DataFrame:
    results_wide = (
        results[['embed', 'norm', 'norm_cat', 'fold', 'r2']]
        .pivot(index=['norm', 'fold', 'norm_cat'], columns='embed', values='r2')
        .reset_index()
    )
    return results_wide

# Pivoting to make it easier to compute pairwise differences
text_behav_wide = pivot_results(text_behav)
text_brain_wide = pivot_results(text_brain)

text_behav_wide
# Out:
# embed            norm  fold             norm_cat  BERT_base&Llama_3_8B  \
# 0      anger_mohammad     1              emotion              0.404855
# 1      anger_mohammad     2              emotion              0.361355
# 2      anger_mohammad     3              emotion              0.352846
# 3      anger_mohammad     4              emotion              0.297719
# 4      anger_mohammad     5              emotion              0.371274
# ...               ...   ...                  ...                   ...
# 1450    weight_binder     1  space/time/quantity              0.703625
# 1451    weight_binder     2  space/time/quantity              0.689771
# 1452    weight_binder     3  space/time/quantity              0.589848
# 1453    weight_binder     4  space/time/quantity              0.555155
# 1454    weight_binder     5  space/time/quantity              0.693952
#
# embed  BERT_base&SVD_SWOW  Llama_3_8B&SVD_SWOW
# 0                0.419995             0.413220
# ...

# %% [markdown]
# ## Plotting

# %%
text_behav_grand
# Out:
#       embed_group                   norm_cat  r2_grand_avg
# 0   text&behavior         age of acquisition      0.591720
# 1   text&behavior                    animacy      0.781283
# 2   text&behavior                    arousal      0.625402
# 3   text&behavior            associatability      0.399907
# 4   text&behavior  auditory lexical decision      0.096556
# 5   text&behavior               concreteness      0.801086
# 6   text&behavior                  dominance      0.631743
# 7   text&behavior                    emotion      0.626395
# 8   text&behavior                familiarity      0.337986
# 9   text&behavior                  frequency      0.783100
# 10  text&behavior                goals/needs      0.612886
# 11  text&behavior     iconicity/transparency      0.350352
# 12  text&behavior               imageability      0.681774
# 13  text&behavior                      motor      0.586961
# 14  text&behavior                     naming      0.177871
# ...

# %%
# Pivot grand averages to wide format for plotting
heat_df_1 = (
    text_behav_grand
    .pivot(index='norm_cat', columns='embed_group', values='r2_grand_avg')
    [['text&text', 'text&behavior']]
)
heat_df_1['text&behavior - text&text'] = heat_df_1['text&behavior'] - heat_df_1['text&text']

# Sort by difference and transpose
heat_df_1 = heat_df_1.sort_values(by='text&behavior - text&text').T
heat_df_1
# Out:
# norm_cat                   visual lexical decision    naming  \
# embed_group
# text&text                                 0.377814  0.213782
# text&behavior                             0.335960  0.177871
# text&behavior - text&text                -0.041854 -0.035911
#
# norm_cat                   auditory lexical decision  frequency  \
# embed_group
# text&text                                   0.132111   0.814388
# text&behavior                               0.096556   0.783100
# text&behavior - text&text                  -0.035555  -0.031288
#
# norm_cat                   semantic neighborhood  recognition memory  \
# embed_group
# text&text                               0.323145            0.452433
# text&behavior                           0.296162            0.426627
# text&behavior - text&text              -0.026982           -0.025807
#
# norm_cat                   semantic diversity  age of acquisition  \
# embed_group
# ...

# %%
heat_df_2 = (
    text_brain_grand
    .pivot(index='norm_cat', columns='embed_group', values='r2_grand_avg')
    [['text&text', 'text&brain']]
)
heat_df_2['text&brain - text&text'] = heat_df_2['text&brain'] - heat_df_2['text&text']

# Sort by text-behavior differences and transpose
heat_df_2 = heat_df_2.T[heat_df_1.columns]
heat_df_2
# Out:
# norm_cat                visual lexical decision    naming  \
# embed_group
# text&text                              0.232546  0.055845
# text&brain                             0.190610  0.029986
# text&brain - text&text                -0.041936 -0.025859
#
# norm_cat                auditory lexical decision  frequency  \
# embed_group
# text&text                                0.068668   0.817614
# text&brain                               0.042581   0.756769
# text&brain - text&text                  -0.026087  -0.060845
#
# norm_cat                semantic neighborhood  recognition memory  \
# embed_group
# text&text                            0.290168            0.409290
# text&brain                           0.234536            0.379701
# text&brain - text&text              -0.055632           -0.029588
#
# norm_cat                semantic diversity  age of acquisition  \
# embed_group
# text&text                         0.809202            0.455398
# ...

# %%
def fix_indices(heat_df: pd.DataFrame) -> pd.DataFrame:
    heat_df.index = heat_df.index.str.replace('&', ' & ').str.title()
    heat_df.columns = heat_df.columns.str.replace('_', ' ')
    return heat_df

heat_df_1, heat_df_2 = fix_indices(heat_df_1), fix_indices(heat_df_2)
heat_df_1
# Out:
# norm_cat                       visual lexical decision    naming  \
# embed_group
# Text & Text                                   0.377814  0.213782
# Text & Behavior                               0.335960  0.177871
# Text & Behavior - Text & Text                -0.041854 -0.035911
#
# norm_cat                       auditory lexical decision  frequency  \
# embed_group
# Text & Text                                     0.132111   0.814388
# Text & Behavior                                 0.096556   0.783100
# Text & Behavior - Text & Text                  -0.035555  -0.031288
#
# norm_cat                       semantic neighborhood  recognition memory  \
# embed_group
# Text & Text                                 0.323145            0.452433
# Text & Behavior                             0.296162            0.426627
# Text & Behavior - Text & Text              -0.026982           -0.025807
#
# norm_cat                       semantic diversity  age of acquisition  \
# embed_group
# ...

# %%
# Function to create a lighter version of a colormap
def lighten_cmap(cmap_name, factor=0.3):
    cmap = plt.cm.get_cmap(cmap_name, 256)  # Get the original colormap
    colors = cmap(np.linspace(0, 1, 256))

    # Blend each color with white
    white = np.array([1, 1, 1, 1])  # RGBA for white
    new_colors = (1 - factor) * colors + factor * white

    return LinearSegmentedColormap.from_list(f'light_{cmap_name}', new_colors)

# Function to visualize a colormap
def plot_colormap(cmap):
    gradient = np.linspace(0, 1, 256)
    gradient = np.vstack((gradient, gradient))

    plt.imshow(gradient, aspect='auto', cmap=cmap)
    plt.axis('off')
    plt.show()

# Usage example:
# Generate a lighter viridis colormap
lighter_viridis = lighten_cmap('viridis', factor=0.6)

# Visualize it
plot_colormap(lighter_viridis)
# Out:
# /var/folders/st/5gbrfvhn687dxwjl5_xg21t40000gq/T/ipykernel_15596/4173034499.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(cmap_name, 256)  # Get the original colormap

# %%
pd.DataFrame(heat_df_1.loc['Text & Behavior - Text & Text']).T
# Out:
# norm_cat                       visual lexical decision    naming  \
# Text & Behavior - Text & Text                -0.041854 -0.035911
#
# norm_cat                       auditory lexical decision  frequency  \
# Text & Behavior - Text & Text                  -0.035555  -0.031288
#
# norm_cat                       semantic neighborhood  recognition memory  \
# Text & Behavior - Text & Text              -0.026982           -0.025807
#
# norm_cat                       semantic diversity  age of acquisition  \
# Text & Behavior - Text & Text           -0.023609           -0.023241
#
# norm_cat                       iconicity/transparency  familiarity  ...  \
# Text & Behavior - Text & Text               -0.018412    -0.015675  ...
#
# norm_cat                       imageability  this/that  goals/needs  \
# Text & Behavior - Text & Text      0.006826    0.00704     0.010637
#
# norm_cat                       space/time/quantity   valence  associatability  \
# ...

# %%
def annotate(heat_df, ax, mask=None):
    for x, norm_cat in enumerate(heat_df.columns):
        for y, embed in enumerate(heat_df.index):
            annot = heat_df.loc[embed, norm_cat]
            
            # Scientific notation
            if abs(annot) > 1e3:
                annot = f'{annot:.1e}'
            elif np.isnan(annot):
                annot = ''
            else:
                annot = f'{annot:.2f}'
            
            # Fontsize and fontweight
            fontsize, fontweight = 13, 'normal'
            if mask is not None:
                if mask.loc[embed, norm_cat]:
                    fontsize, fontweight = 16, 'bold'
                
            ax.text(
                x + .5, y + .5, annot, fontsize=fontsize, fontweight=fontweight,
                ha='center', va='center', color='black'
            )

# Splitting up heat dfs into sub-panels
heat_df_1a = heat_df_1.loc[['Text & Text', 'Text & Behavior']]
heat_df_1b = pd.DataFrame(heat_df_1.loc['Text & Behavior - Text & Text']).T

heat_df_2a = heat_df_2.loc[['Text & Text', 'Text & Brain']]
heat_df_2b = pd.DataFrame(heat_df_2.loc['Text & Brain - Text & Text']).T

heat_dfs = [heat_df_1a, heat_df_1b, heat_df_2a, heat_df_2b]
fig, axs = plt.subplots(4, figsize=(18, 6), height_ratios=[len(df) for df in heat_dfs])

# heat_df_1a
sns.heatmap(
    heat_df_1a, cmap=lighter_viridis, vmin=0,
    vmax=1, annot=False, fmt='', cbar=False,
    ax=axs[0]
)

# heat_df_1b
sns.heatmap(
    heat_df_1b.abs(), cmap=lighter_viridis, annot=False, fmt='',
    cbar=False, ax=axs[1]
)

# heat_df_2a
sns.heatmap(
    heat_df_2a, cmap=lighter_viridis, vmin=0,
    vmax=1, annot=False, fmt='', cbar=False,
    ax=axs[2]
)

# heat_df_2b
sns.heatmap(
    heat_df_2b.abs(), cmap=lighter_viridis, annot=False, fmt='',
    cbar=False, ax=axs[3]
)

for ax in axs:
    ax.set(xlabel='', ylabel='')
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=13)
    ax.set_xticklabels([], fontsize=13)
    
    # rotates y-tick labels to horizontal
    plt.setp(ax.get_yticklabels(), rotation=0)

# Remove x-tick labels for all but last plot
x_tick_labels = heat_df_1.columns.str.title().str.replace('Of', 'of', regex=True)
axs[-1].set_xticklabels(x_tick_labels, rotation=90, ha='right')

# Annotates cells
annotate(heat_df_1a, axs[0])
annotate(heat_df_1b, axs[1])
annotate(heat_df_2a, axs[2])
annotate(heat_df_2b, axs[3])

# Sets axis titles
axs[0].set_title('Average Test $R^2$', fontsize=20)
  
fig.tight_layout()
# plt.savefig('../../figures/rca_text_brain.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Descriptive Stats and Significance Tests

# %%
def compute_results_diffs(results_wide: pd.DataFrame, text_1: str, text_2: str, compar: str) -> (pd.DataFrame, pd.DataFrame):
    # Defining ensemble names
    text_text = text_1 + '&' + text_2
    text_1_compar = text_1 + '&' + compar
    text_2_compar = text_2 + '&' + compar

    # Fold-wise differences
    results_wide[f'{text_1_compar} vs {text_text}'] = results_wide[text_1_compar] - results_wide[text_text]
    results_wide[f'{text_2_compar} vs {text_text}'] = results_wide[text_2_compar] - results_wide[text_text]

    # Dropping absolute results
    results_wide = results_wide.drop(columns=[text_text, text_1_compar, text_2_compar])

    # Converting to long format for averaging
    results_diffs = results_wide.melt(id_vars=['norm', 'norm_cat', 'fold']).rename(columns={'embed': 'comparing'})

    return results_diffs

# Computing fold-wise differences
text_behav_diffs = compute_results_diffs(text_behav_wide, 'BERT_base', 'Llama_3_8B', 'SVD_SWOW')
text_brain_diffs = compute_results_diffs(text_brain_wide, 'BERT_base', 'Llama_3_8B', 'EEG_speech')

text_behav_diffs

# %%
def get_fold_wise_diffs(results_diffs: pd.DataFrame, norm_cat: str) -> pd.DataFrame:
    # Averaging diffs across folds
    fold_diffs = (
        results_diffs.query(f'norm_cat == "{norm_cat}"')
        .groupby(['norm', 'fold'])
        .mean(numeric_only=True)['value']
    )
    return fold_diffs


def wilcoxon_test(diffs):
    """Does the same as above but with wilcoxon instead of t"""
    w, p = wilcoxon(diffs)
    return {
        'median': round(diffs.median(), 2),
        'n': len(diffs), 'w': w, 'p': p
    }

# True if the difference is significant
heat_df_2_sigs = pd.Series(dtype=bool, index=heat_df_2.columns)
for norm_cat in heat_df_2.columns:
    diffs = get_fold_wise_diffs(text_behav_diffs, norm_cat)
    p = wilcoxon_test(diffs)['p']
    heat_df_2_sigs[norm_cat] = p < 0.05

# Reshapes heat_df_2_sigs to match heat_df_2
heat_df_2_sigs = heat_df_2_sigs.to_frame().T
heat_df_2_sigs.index = ['Text & Behavior - Text & Text']
heat_df_2_sigs

# %%
heat_df_2.loc['Text & Behavior - Text & Text'].sort_values().round(2)

# %%
# checking that ensembling always improves performance
print(f"Text & Text - Text: {(heat_df_1.loc['Text & Text'] - heat_df_1.loc['Text'] < 0).any()}")
print(f"Text & Behavior - Behavior: {(heat_df_1.loc['Text & Behavior'] - heat_df_1.loc['Behavior'] < 0).any()}")

# %%
print(f"# where Text & Behavior > Text & Text: {(heat_df_2.loc['Text & Behavior - Text & Text'] > 0).sum()}")
