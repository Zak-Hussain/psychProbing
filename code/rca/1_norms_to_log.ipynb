# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
norms = pd.read_csv('../../data/psychNorms/psychNorms.zip', index_col=0, compression='zip', low_memory=False)
norm_metadata = pd.read_csv('../../data/psychNorms/psychNorms_metadata.csv', index_col='norm')
norm_metadata['associated_embed'] = norm_metadata['associated_embed'].astype(str)
norms
# Out:
#              Freq_HAL  Freq_KF  Freq_SUBTLEXUS  Freq_SUBTLEXUK  Freq_Blog  \
# 'em               0.0      NaN             NaN             NaN        NaN
# 'neath            0.0      NaN             NaN             NaN        NaN
# 're               0.0      NaN             NaN             NaN        NaN
# 'shun             0.0      NaN             NaN             NaN        NaN
# 'tis              0.0      NaN             NaN             NaN        NaN
# ...               ...      ...             ...             ...        ...
# shrick            NaN      NaN             NaN             NaN        NaN
# post office       NaN      NaN             NaN             NaN        NaN
# fishing rod       NaN      NaN             NaN             NaN        NaN
# March             NaN      NaN             NaN             NaN        NaN
# May               NaN      NaN             NaN             NaN        NaN
#
#              Freq_Twitter  Freq_News  Freq_CobW  Freq_CobS  CD_SUBTLEXUS  ...  \
# 'em                   NaN        NaN     1.3617     1.9138           NaN  ...
# 'neath                NaN        NaN     0.0000     0.0000           NaN  ...
# 're                   NaN        NaN     0.9031     1.6335           NaN  ...
# 'shun                 NaN        NaN     0.0000     0.0000           NaN  ...
# 'tis                  NaN        NaN     0.4771     0.6021           NaN  ...
# ...                   ...        ...        ...        ...           ...  ...
# shrick                NaN        NaN        NaN        NaN           NaN  ...
# post office           NaN        NaN        NaN        NaN           NaN  ...
# fishing rod           NaN        NaN        NaN        NaN           NaN  ...
# March                 NaN        NaN        NaN        NaN           NaN  ...
# May                   NaN        NaN        NaN        NaN           NaN  ...
#
#              reproduction_vanarsdall  person_vanarsdall  goals_vanarsdall  \
# 'em                              NaN                NaN               NaN
# 'neath                           NaN                NaN               NaN
# 're                              NaN                NaN               NaN
# 'shun                            NaN                NaN               NaN
# 'tis                             NaN                NaN               NaN
# ...                              ...                ...               ...
# shrick                           NaN                NaN               NaN
# post office                      NaN                NaN               NaN
# fishing rod                      NaN                NaN               NaN
# March                            NaN                NaN               NaN
# May                              NaN                NaN               NaN
#
#              movement_vanarsdall  concreteness_vanarsdall  \
# 'em                          NaN                      NaN
# 'neath                       NaN                      NaN
# 're                          NaN                      NaN
# 'shun                        NaN                      NaN
# 'tis                         NaN                      NaN
# ...                          ...                      ...
# shrick                       NaN                      NaN
# post office                  NaN                      NaN
# fishing rod                  NaN                      NaN
# March                        NaN                      NaN
# May                          NaN                      NaN
#
#              familiarity_vanarsdall  imageability_vanarsdall  \
# 'em                             NaN                      NaN
# 'neath                          NaN                      NaN
# 're                             NaN                      NaN
# 'shun                           NaN                      NaN
# 'tis                            NaN                      NaN
# ...                             ...                      ...
# shrick                          NaN                      NaN
# post office                     NaN                      NaN
# fishing rod                     NaN                      NaN
# March                           NaN                      NaN
# May                             NaN                      NaN
#
#              familiarity_fear  aoa_fear  imageability_fear
# 'em                       NaN       NaN                NaN
# 'neath                    NaN       NaN                NaN
# 're                       NaN       NaN                NaN
# 'shun                     NaN       NaN                NaN
# 'tis                      NaN       NaN                NaN
# ...                       ...       ...                ...
# shrick                   2.62      4.38               2.93
# post office              3.79      3.07               5.29
# fishing rod              2.29      3.38               5.64
# March                    3.43      2.76               3.50
# May                      4.10      2.86               2.79
#
# [107085 rows x 292 columns]

# %%
# Identifying count-based norms to investigate which need log transformation
numeric_norms = norm_metadata.query('type == "numeric"').index
count_norms = [norm for norm in numeric_norms if norms[norm].dropna().apply(float.is_integer).all()]
norm_metadata.loc[count_norms]
# Out:
#                                                                description  \
# norm
# Nsenses_WordNet            Number of senses based on the WordNet database.
# Nsenses_Wordsmyth        Number of senses based on the Wordsmyth dictio...
# Nmeanings_Wordsmyth      Number of meanings based on the Wordsmyth dict...
# Nmeanings_Websters       Number of meanings based on the Websters dicti...
# NFeatures                Number of features listed for the word. This m...
# Sem_N                    The number of semantic neighbors within a thre...
# Assoc_Freq_Token123      The number of times that a word is one of the ...
# Cue_SetSize              The number of different responses or targets g...
# likableness_anderson     Likableness ratings on a scale from 0 (least f...
# meaningfulness_anderson  Meaningfulness ratings on a scale from 0 ("I h...
# living_vanarsdall        Ratings from 1 (high nonliving) to 7 (high liv...
# thought_vanarsdall       Ratings form 1 (low ability to think) to 7 (hi...
# reproduction_vanarsdall  Ratings from 1 (low ability to reproduce) to 7...
# person_vanarsdall        Ratings from 1 (low similarity to a person) to...
# goals_vanarsdall         Ratings from 1 (low goal directedness) to 7 (h...
# movement_vanarsdall      Ratings from 1 (low movement likelihood) to 7 ...
# concreteness_vanarsdall  Ratings from 1 (highly abstract) to 7 (highty ...
# familiarity_vanarsdall   Ratings from 1 (highly unfamiliar) to 7 (highl...
#
#                                                                   citation  \
# norm
# Nsenses_WordNet          Miller, G. A. (1995). "WordNet: a lexical data...
# Nsenses_Wordsmyth        Rice, C. A., et al. (2019). "A comparison of h...
# Nmeanings_Wordsmyth      Rice, C. A., et al. (2019). "A comparison of h...
# Nmeanings_Websters       Gao, C., Shinkareva, S. V., & Desai, R. H. "SC...
# NFeatures                Buchanan, E. M., et al. (2019). "English seman...
# Sem_N                    Shaoul, C. and C. Westbury (2006). "Word frequ...
# Assoc_Freq_Token123      De Deyne, S., et al. (2019). "The “Small World...
# Cue_SetSize              Nelson, D. L., et al. (2004). "The University ...
# likableness_anderson     @article{anderson1968likableness,\n  title={Li...
# meaningfulness_anderson  @article{anderson1968likableness,\n  title={Li...
# living_vanarsdall        @article{vanarsdall2022analyzing,\n  title={An...
# thought_vanarsdall       @article{vanarsdall2022analyzing,\n  title={An...
# reproduction_vanarsdall  @article{vanarsdall2022analyzing,\n  title={An...
# person_vanarsdall        @article{vanarsdall2022analyzing,\n  title={An...
# goals_vanarsdall         @article{vanarsdall2022analyzing,\n  title={An...
# movement_vanarsdall      @article{vanarsdall2022analyzing,\n  title={An...
# concreteness_vanarsdall  @article{vanarsdall2022analyzing,\n  title={An...
# familiarity_vanarsdall   @article{vanarsdall2022analyzing,\n  title={An...
#
#                                       category  \
# norm
# Nsenses_WordNet             semantic_diversity
# Nsenses_Wordsmyth           semantic_diversity
# Nmeanings_Wordsmyth         semantic_diversity
# Nmeanings_Websters          semantic_diversity
# NFeatures                   number_of_features
# Sem_N                    semantic_neighborhood
# Assoc_Freq_Token123      semantic_neighborhood
# Cue_SetSize              semantic_neighborhood
# likableness_anderson              social/moral
# meaningfulness_anderson            familiarity
# living_vanarsdall                      animacy
# thought_vanarsdall                     animacy
# reproduction_vanarsdall                animacy
# person_vanarsdall                      animacy
# goals_vanarsdall                       animacy
# movement_vanarsdall                    animacy
# concreteness_vanarsdall           concreteness
# familiarity_vanarsdall             familiarity
#
#                                                           associated_embed  \
# norm
# Nsenses_WordNet                                                        nan
# Nsenses_Wordsmyth                                                      nan
# Nmeanings_Wordsmyth                                                    nan
# Nmeanings_Websters                                                     nan
# NFeatures                                                              nan
# Sem_N                                                                  nan
# Assoc_Freq_Token123      PPMI_SVD_SWOW SGSoftMaxInput_SWOW SGSoftMaxOut...
# Cue_SetSize                                                            nan
# likableness_anderson                                                   nan
# meaningfulness_anderson                                                nan
# living_vanarsdall                                                      nan
# thought_vanarsdall                                                     nan
# reproduction_vanarsdall                                                nan
# person_vanarsdall                                                      nan
# goals_vanarsdall                                                       nan
# movement_vanarsdall                                                    nan
# concreteness_vanarsdall                                                nan
# familiarity_vanarsdall                                                 nan
#
#                             type  n_ratings
# norm
# Nsenses_WordNet          numeric      40480
# Nsenses_Wordsmyth        numeric        534
# Nmeanings_Wordsmyth      numeric        534
# Nmeanings_Websters       numeric      40945
# NFeatures                numeric       4381
# Sem_N                    numeric      52008
# Assoc_Freq_Token123      numeric      29722
# Cue_SetSize              numeric       4954
# likableness_anderson     numeric        555
# meaningfulness_anderson  numeric        555
# living_vanarsdall        numeric       1200
# thought_vanarsdall       numeric       1200
# reproduction_vanarsdall  numeric       1200
# person_vanarsdall        numeric       1200
# goals_vanarsdall         numeric       1200
# movement_vanarsdall      numeric       1200
# concreteness_vanarsdall  numeric       1200
# familiarity_vanarsdall   numeric       1200

# %%
# Dropping norms that were wrongly identified as count-based using automatic method above
count_norms = [
    'Nsenses_WordNet', 'Nsenses_Wordsmyth', 'Nmeanings_Wordsmyth', 'Nmeanings_Websters', 
    'NFeatures', 'Sem_N', 'Assoc_Freq_Token123', 'Cue_SetSize'
]


rt_norms = [norm for norm in numeric_norms if 'rt_' in norm.lower()]
norm_metadata.loc[rt_norms]
# Out:
#                                                                description  \
# norm
# LexicalD_RT_V_ELP        The mean visual lexical decision latency (in m...
# LexicalD_RT_V_ECP        The mean visual lexical decision latency (in m...
# LexicalD_RT_V_BLP        The mean visual lexical decision latency (in m...
# LexicalD_RT_A_MALD       The mean auditory lexical decision latency (in...
# LexicalD_RT_A_AELP       The mean auditory lexical decision latency (in...
# Naming_RT_ELP            The mean naming latency (in msec) for a partic...
# SemanticD_RT_Calgary     The mean latency (in msec) of concrete/abstrac...
# Short_Binder             Short ratings on a scale from 0 (Not at all) t...
# rt_khanna                Reaction time (milliseconds) for performing th...
# rt_ley                        Mean time between cue and response (seconds)
# rt_chiarello              time from the onset ofthe stimulus\nward unti...
# rt_chen                   Mean time taken to decide if the word was known.
# aoa_rt_cortese             Mean time taken to perform the aoa rating task.
# imageability_rt_cortese  Reaction time (milliseconds) for performing th...
# rt_schock                                 Reaction times for aoa ratings.
#
#                                                                   citation  \
# norm
# LexicalD_RT_V_ELP        Balota, D. A., et al. (2007). "The English lex...
# LexicalD_RT_V_ECP        Mandera, P., et al. (2019). "Recognition times...
# LexicalD_RT_V_BLP        Keuleers, E., et al. (2012). "The British Lexi...
# LexicalD_RT_A_MALD       Tucker, B. V., et al. (2019). "The massive aud...
# LexicalD_RT_A_AELP       Goh, W. D., et al. (2020). "The Auditory Engli...
# Naming_RT_ELP            Balota, D. A., et al. (2007). "The English lex...
# SemanticD_RT_Calgary     Pexman, P. M., et al. (2017). "The Calgary sem...
# Short_Binder             Binder, J. R., Conant, L. L., Humphries, C. J....
# rt_khanna                @article{khanna2011age,\n  title={Age of acqui...
# rt_ley                   @article{ley1975associative,\n  title={Associa...
# rt_chiarello             @article{chiarello1999imageability,\n  title={...
# rt_chen                  @article{chen2019evaluating,\n  title={Evaluat...
# aoa_rt_cortese           @article{cortese2008age,\n  title={Age of acqu...
# imageability_rt_cortese  @article{cortese2004imageability,\n  title={Im...
# rt_schock                @article{schock2012age,\n  title={Age of acqui...
#
#                                            category associated_embed     type  \
# norm
# LexicalD_RT_V_ELP           visual_lexical_decision              nan  numeric
# LexicalD_RT_V_ECP           visual_lexical_decision              nan  numeric
# LexicalD_RT_V_BLP           visual_lexical_decision              nan  numeric
# LexicalD_RT_A_MALD       autidtory_lexical_decision              nan  numeric
# LexicalD_RT_A_AELP       autidtory_lexical_decision              nan  numeric
# Naming_RT_ELP                                naming              nan  numeric
# SemanticD_RT_Calgary              semantic_decision              nan  numeric
# Short_Binder                    space/time/quantity    compo_attribs  numeric
# rt_khanna                         semantic_decision              nan  numeric
# rt_ley                            semantic_decision              nan  numeric
# rt_chiarello                      semantic_decision              nan  numeric
# rt_chen                           semantic_decision              nan  numeric
# aoa_rt_cortese                    semantic_decision              nan  numeric
# imageability_rt_cortese           semantic_decision              nan  numeric
# rt_schock                         semantic_decision              nan  numeric
#
#                          n_ratings
# norm
# LexicalD_RT_V_ELP            40467
# LexicalD_RT_V_ECP            61851
# LexicalD_RT_V_BLP            28514
# LexicalD_RT_A_MALD           26522
# LexicalD_RT_A_AELP           10081
# Naming_RT_ELP                40480
# SemanticD_RT_Calgary          9999
# Short_Binder                   534
# rt_khanna                     1314
# rt_ley                         382
# rt_chiarello                  1196
# rt_chen                        370
# aoa_rt_cortese                3000
# imageability_rt_cortese       3000
# rt_schock                     3000

# %%
# Dropping norms that were wrongly identified as reaction time-based using automatic method above
rt_norms.remove('Short_Binder')

# Log transforming remaining count norms
to_log = count_norms + rt_norms
norms[to_log] = norms[to_log].apply(np.log1p)

# Checking it roughly worked
for norm in to_log:
    print(norm)
    norms[norm].hist()
    plt.show()
# Out:
# Nsenses_WordNet
# Nsenses_Wordsmyth
# Nmeanings_Wordsmyth
# Nmeanings_Websters
# NFeatures
# Sem_N
# Assoc_Freq_Token123
# Cue_SetSize
# LexicalD_RT_V_ELP
# LexicalD_RT_V_ECP
# LexicalD_RT_V_BLP
# LexicalD_RT_A_MALD
# LexicalD_RT_A_AELP
# Naming_RT_ELP
# SemanticD_RT_Calgary
# rt_khanna
# rt_ley
# rt_chiarello
# rt_chen
# aoa_rt_cortese
# imageability_rt_cortese
# rt_schock

# %%
# Saves as
pd.DataFrame(to_log, columns=['norm']).to_csv('../../data/norms_to_log.csv', index=False)
