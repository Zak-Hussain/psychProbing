# %%
import pandas as pd

# %%
# NEED TO UPDATE TO ACTUAL TOP
baseline = pd.read_csv('../../data/embeds/BERT_base.csv', index_col=0, header=None)
behavior = pd.read_csv('../../data/embeds/SVD_SWOW.csv', index_col=0)
brain = pd.read_csv('../../data/embeds/fMRI_speech_cognival.csv', index_col=0)

baseline, behavior.shape, brain.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # NEED TO UPDATE TO ACTUAL TOP
# ----> 2 baseline = pd.read_csv('../../data/embeds/BERT_base.csv', index_col=0, header=None)
#       3 behavior = pd.read_csv('../../data/embeds/SVD_SWOW.csv', index_col=0)
#       4 brain = pd.read_csv('../../data/embeds/fMRI_speech_cognival.csv', index_col=0)
#
# NameError: name 'pd' is not defined
